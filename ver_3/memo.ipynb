# %%
import phthalicacid as pa
import pandas as pd

df = pd.read_excel("data/samples_data.xlsx")
print(df.head())
# Out:
#               化合物名        cas                                   smiles
# 0             フタル酸    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O
# 1  2,3-ナフタレンジカルボン酸  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O
# 2          ピロメリット酸    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O
# 3        4-ニトロフタル酸   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O
# 4        3-ニトロフタル酸   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O

# %%
df = pa.select_smiles(df)
print(df.head())
# Out:
#               化合物名        cas                                   smiles
# 0             フタル酸    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O
# 1  2,3-ナフタレンジカルボン酸  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O
# 2          ピロメリット酸    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O
# 3        4-ニトロフタル酸   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O
# 4        3-ニトロフタル酸   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O

# %%
df = pa.detect_phthalic_acid(df)
print(df["cooh"])
# Out:
# 0        [[8, 7, 10, 9, 16], [1, 2, 0, 11, 17]]
# 1     [[12, 11, 14, 13, 22], [1, 2, 0, 15, 23]]
# 2        [[9, 8, 11, 10, 20], [5, 4, 7, 6, 19]]
# 3        [[9, 8, 10, 11, 19], [1, 3, 0, 2, 15]]
# 4        [[9, 8, 10, 11, 19], [1, 3, 0, 2, 15]]
# 5         [[6, 5, 8, 7, 47], [1, 2, 0, 44, 62]]
# 6         [[6, 5, 8, 7, 34], [1, 2, 0, 31, 45]]
# 7     [[42, 41, 44, 43, 66], [1, 2, 0, 45, 67]]
# 8       [[6, 5, 8, 7, 23], [10, 9, 12, 11, 24]]
# 9       [[6, 5, 8, 7, 19], [10, 9, 12, 11, 20]]
# 10        [[4, 3, 6, 5, 17], [8, 7, 10, 9, 18]]
# 11    [[19, 18, 21, 20, 33], [1, 2, 0, 22, 34]]
# 12    [[25, 24, 27, 26, 41], [1, 2, 0, 28, 42]]
# 13        [[6, 5, 8, 7, 28], [1, 2, 0, 25, 41]]
# 14    [[22, 21, 24, 23, 40], [1, 2, 0, 25, 41]]
# 15        [[6, 5, 8, 7, 34], [1, 2, 0, 31, 49]]
# 16        [[6, 5, 8, 7, 30], [1, 2, 0, 27, 47]]
# 17      [[6, 5, 8, 7, 15], [10, 9, 12, 11, 16]]
# 18       [[9, 8, 11, 10, 28], [5, 4, 7, 6, 27]]
# 19       [[8, 7, 10, 9, 17], [1, 2, 0, 14, 20]]
# ...

# %%
pa.generate_coord(df,23)

# %%
pa.save_data(df)

# %%
import pandas as pd
df = pd.read_csv("out/save/samples.csv")
print(df)
# Out:
#            cas                                             smiles  h1  h2
# 0      88-99-3                            O=C(C1=CC=CC=C1C(O)=O)O  17  16
# 1    2169-87-1                    O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  23  22
# 2      89-05-4            O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  19  20
# 3     610-27-5                   O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15  19
# 4     603-11-2                   O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  15  19
# 5           te  O=C(C(C=C1)=C(C(O)=O)C=C1OC2=CC(OC3=CC=C(C(O)=...  62  47
# 6           de  O=C(C(C=C1)=C(C(O)=O)C=C1OC2=CC=CC(OC3=CC(C(O)...  45  34
# 7           ee  O=C(C1=CC(OC(C=C2)=CC=C2OC3=CC(OC4=CC=C(OC5=CC...  67  66
# 8   27485-15-0  O=C1C2=C(C=C(C(O)=O)C(C(O)=O)=C2)C(C3=CC=CC=C3...  24  23
# 9    1885-13-8                      COC1=CC=C(C(O)=O)C(C(O)=O)=C1  20  19
# 10  14963-97-4                      COC1=C(C(O)=O)C(C(O)=O)=CC=C1  18  17
# 11        4-no      O=C(C1=CC(OC2=CC3=CC=CC=C3C=C2)=CC=C1C(O)=O)O  34  33
# ...

# %%
import phthalicacid as pa
pa.make_ion_file(df, "model_data")

# %%
import phthalicacid as pa
import pandas as pd

df = pd.read_excel("data/samples_data.xlsx")
df1 = df["化合物名"]
df2 = df["cas"]
df3 = df["smiles"]
dfx = pd.concat([df2,df3],axis=1,keys=["CAS","SMILES"])
print(dfx.head())

# %%
dfx.loc[1, "CAS"] = None
print(dfx.head())
dfx.drop(1,inplace=True)
dfx.reset_index(drop=True, inplace=True)
print(dfx.head())

# %%
dfx.loc[1, "COOH"] = "a"
dfx.at[3, "COOH"] = [[1,2,3],[2,3,4]]
dfx.at[4, "COOH"] = [[8, 7, 10, 9, 16], [1, 2, 0, 11, 17]]
print(dfx.head())
print(dfx.loc[3, "COOH"][0][1])

# %%
import pandas as pd
df = pd.read_excel("data/samples_data.xlsx")
if "iso" in df.columns:
    print("yes")
else:
    print("no")

# %%
for i, j, k in zip(range(20), range(10, 15), range(100, 110)):
    print(i, j, k)

# %%
print(max(1,2))

# %%
import pandas as pd
a = [None, 2, None, 4]
b = [1,2,3,4]
c = [4,3,2,1]

df = pd.DataFrame({"A":a, "B":b, "C":c})
print(df)
df = df.dropna(how="any").reset_index(drop=True)
print(df[["A", "B"]])
# Out:
#      A  B  C
# 0  NaN  1  4
# 1  2.0  2  3
# 2  NaN  3  2
# 3  4.0  4  1
#      A  B
# 0  2.0  2
# 1  4.0  4

# %% [markdown]
# ---

# %%
import dft_calc as dc

df = pd.read_csv("out/save/samples.csv")
df = dc.delta_g(df)
print(df.head())
# Out:
#          cas                                   smiles  h1  h2  delta_g_hartree
# 0    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O  17  16         0.438380
# 1  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  23  22         0.438607
# 2    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  19  20         0.434274
# 3   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15  19         0.433323
# 4   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  15  19         0.434331

# %%
df = dc.dipole_moment(df)

# %%
df = dc.homolumo(df)

# %%
df.drop(columns=["molecular_volume_A3"], inplace=True)

# %%
df.to_csv("out/save/value.csv", index=False)

# %%
import pandas as pd
import dft_calc as dc

df = pd.read_csv("out/save/value.csv")
df = dc.molecular_volume(df)
print(df.head())
# Out:
#          cas                                   smiles  h1  h2  \
# 0    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O  17  16
# 1  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  23  22
# 2    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  19  20
# 3   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15  19
# 4   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  15  19
#
#    delta_g_hartree  dipole_moment_debye   homo_ev   lumo_ev    gap_ev  \
# 0         0.438380             1.282205 -8.984111 -0.688720  8.295391
# 1         0.438607             2.529908 -7.840416 -0.689536  7.150880
# 2         0.434274             4.369587 -9.310375 -1.383427  7.926949
# 3         0.433323             6.392675 -9.433915 -1.997860  7.436055
# 4         0.434331             5.063714 -9.406432 -1.915954  7.490478
#
#    molecular_volume_A3
# 0              139.352
# 1              182.672
# 2              194.608
# 3              162.832
# 4              162.368

# %%
df.to_csv("out/save/value.csv", index=False)

# %%
import pandas as pd
import dft_calc as dc


df = pd.read_csv("out/save/value.csv")
df = dc.nbo_charge(df)
print(df.head())
# Out:
#          cas                                   smiles  h1  h2  \
# 0    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O  17  16
# 1  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  23  22
# 2    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  19  20
# 3   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15  19
# 4   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  15  19
#
#    delta_g_hartree  dipole_moment_debye   homo_ev   lumo_ev    gap_ev  \
# 0         0.438380             1.282205 -8.984111 -0.688720  8.295391
# 1         0.438607             2.529908 -7.840416 -0.689536  7.150880
# 2         0.434274             4.369587 -9.310375 -1.383427  7.926949
# 3         0.433323             6.392675 -9.433915 -1.997860  7.436055
# 4         0.434331             5.063714 -9.406432 -1.915954  7.490478
#
#    molecular_volume_A3  nbo_charge
# 0              139.352     0.53188
# 1              182.672     0.53189
# 2              194.608     0.53563
# ...

# %%
df.to_csv("out/save/value.csv", index=False)

# %%
import pandas as pd
import dft_calc as dc

df = pd.read_csv("out/save/value.csv")
df = dc.get_data(df)
print(df.head())
# Out:
#          cas                                   smiles  h1  h2  3and6  4and5  \
# 0    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O  17  16      0      0
# 1  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  23  22      0      2
# 2    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  19  20      0      2
# 3   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15  19      0      1
# 4   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  15  19      1      0
#
#    delta_g_hartree   homo_ev   lumo_ev    gap_ev  dipole_moment_debye  \
# 0         0.438380 -8.984111 -0.688720  8.295391             1.282205
# 1         0.438607 -7.840416 -0.689536  7.150880             2.529908
# 2         0.434274 -9.310375 -1.383427  7.926949             4.369587
# 3         0.433323 -9.433915 -1.997860  7.436055             6.392675
# 4         0.434331 -9.406432 -1.915954  7.490478             5.063714
#
#    molecular_volume_A3  nbo_charge
# 0              139.352     0.53188
# ...

# %%
df.to_csv("out/save/value.csv", index=False)

# %%
import pandas as pd

df1 = pd.read_excel("data/samples_data.xlsx")
df2 = pd.read_csv("out/save/value.csv")
df = pd.concat([df2, df1["yield"]], axis=1)
df.to_csv("out/save/value.csv", index=False)

# %%
import pandas as pd
df = pd.read_excel("data/samples_data.xlsx")
df["test"] = 0
print(df.head())
# Out:
#               化合物名        cas                                   smiles  yield  \
# 0             フタル酸    88-99-3                  O=C(C1=CC=CC=C1C(O)=O)O  13.32
# 1  2,3-ナフタレンジカルボン酸  2169-87-1          O=C(C1=CC2=CC=CC=C2C=C1C(O)=O)O  11.80
# 2          ピロメリット酸    89-05-4  O=C(C1=CC(C(O)=O)=C(C(O)=O)C=C1C(O)=O)O  11.53
# 3        4-ニトロフタル酸   610-27-5         O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  15.65
# 4        3-ニトロフタル酸   603-11-2         O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  12.49
#
#    test
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %% [markdown]
# ---

# %%
import phthalicacid as pa

df = pa.samples_data()
print(df.head())
# Out:
#         cas                            smiles  iso
# 0  877-24-7       [K].O=C(O)C=1C=CC=CC1C(=O)O  NaN
# 1   88-99-3           O=C(O)C=1C=CC=CC1C(=O)O  NaN
# 2  603-11-2  O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  NaN
# 3  610-35-5        O=C(O)C1=CC=C(O)C=C1C(=O)O  NaN
# 4  610-27-5  O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  NaN

# %%
df = pa.select_smiles(df)
print(df.head())
# Out:
#           cas                            smiles  iso
# 0     88-99-3           O=C(O)C=1C=CC=CC1C(=O)O  NaN
# 1    603-11-2  O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  NaN
# 2    610-35-5        O=C(O)C1=CC=C(O)C=C1C(=O)O  NaN
# 3    610-27-5  O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  NaN
# 4  18959-31-4     O=C(O)C1=CC(F)=C(F)C=C1C(=O)O  NaN

# %%
df = pa.detect_phthalic_acid(df)
print(df.head())
# Out:
#           cas                            smiles  iso  \
# 0     88-99-3           O=C(O)C=1C=CC=CC1C(=O)O  NaN
# 1    603-11-2  O=C(O)C1=CC=CC(=C1C(=O)O)N(=O)=O  NaN
# 2    610-35-5        O=C(O)C1=CC=C(O)C=C1C(=O)O  NaN
# 3    610-27-5  O=C(O)C1=CC=C(C=C1C(=O)O)N(=O)=O  NaN
# 4  18959-31-4     O=C(O)C1=CC(F)=C(F)C=C1C(=O)O  NaN
#
#                                        cooh
# 0    [[9, 8, 10, 11, 17], [1, 3, 0, 2, 12]]
# 1    [[9, 8, 10, 11, 19], [1, 3, 0, 2, 15]]
# 2   [[10, 9, 11, 12, 18], [1, 3, 0, 2, 13]]
# 3    [[9, 8, 10, 11, 19], [1, 3, 0, 2, 15]]
# 4  [[11, 10, 12, 13, 17], [1, 3, 0, 2, 14]]

# %%
pa.generate_coord(df)

# %%
pa.save_data(df, name="unknown")

# %%
import pandas as pd

df = pd.read_csv("out/save/unknown.csv")
df = df.head(200)

# %%
import dft_calc as dc

df = dc.homolumo(df,"samples_1-100")
print(df)

# %%
df = dc.homolumo(df,"samples_101-200")

# %%
df = dc.dipole_moment(df, "samples_1-100")
df = dc.dipole_moment(df, "samples_101-200")

# %%
df.to_csv("out/save/unknown_1-200.csv",index=False)

# %%
import rdkit_calc as rc

df = rc.sub_idx(df)

# %%
df.to_csv("out/save/unknown_1-200.csv",index=False)
